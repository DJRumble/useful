# %%
import pandas as pd

# %%
df_election = pd.read_csv('HoC-GE2019-by-constituency.csv')
df_ref = pd.read_csv('EU-referendum-result-data.csv')

# %%
df_election.head()
# Out:
#       ons_id ons_region_id   constituency_name     county_name region_name  \
# 0  W07000049     W92000004            Aberavon  West Glamorgan       Wales
# 1  W07000058     W92000004           Aberconwy           Clwyd       Wales
# 2  S14000001     S92000003      Aberdeen North        Scotland    Scotland
# 3  S14000002     S92000003      Aberdeen South        Scotland    Scotland
# 4  S14000003     S92000003  Airdrie and Shotts        Scotland    Scotland
#
#   country_name constituency_type  declaration_time mp_firstname mp_surname  \
# 0        Wales            County  13/12/2019 02:30      Stephen    Kinnock
# 1        Wales            County  13/12/2019 03:09        Robin     Millar
# 2     Scotland           Borough  13/12/2019 03:13       Kirsty   Blackman
# 3     Scotland           Borough  13/12/2019 03:34      Stephen      Flynn
# 4     Scotland            County  13/12/2019 02:59         Neil       Gray
#
# ...

# %%
df_ref.head()
# Out:
#     id Region_Code Region  Area_Code             Area  Electorate  \
# 0  108   E12000006   East  E06000031     Peterborough      120892
# 1  109   E12000006   East  E06000032            Luton      127612
# 2  112   E12000006   East  E06000033  Southend-on-Sea      128856
# 3  113   E12000006   East  E06000034         Thurrock      109897
# 4  110   E12000006   East  E06000055          Bedford      119530
#
#    ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  \
# 0            87474                 87469        72.35       87469  ...
# 1            84633                 84636        66.31       84616  ...
# 2            93948                 93939        72.90       93939  ...
# 3            79969                 79954        72.75       79950  ...
# 4            86136                 86136        72.06       86135  ...
#
#    Remain_pct  Leave_pct  Rejected_Ballots  No_official_mark  \
# 0    0.391066   0.608934                77                 0
# ...

# %%
#Agg on region
df_ref_agg_rgion = df_ref.groupby(['Region']).sum().reset_index()
df_ref_agg_rgion['Remain_pct'] = df_ref_agg_rgion['Remain']/df_ref_agg_rgion['Valid_Votes']
df_ref_agg_rgion['Leave_pct'] = df_ref_agg_rgion['Leave']/df_ref_agg_rgion['Valid_Votes']
df_ref_agg_rgion['region_name'] = df_ref_agg_rgion['Region']
df_ref_agg_rgion.head()
# Out:
#           Region     id  Electorate  ExpectedBallots  VerifiedBallotPapers  \
# 0           East  11428     4398796          3331637               3331459
# 1  East Midlands  10451     3384299          2510653               2510561
# 2         London    561     5424768          3781355               3781234
# 3     North East    786     1934341          1341474               1341387
# 4     North West   5583     5241568          3668740               3668629
#
#    Pct_Turnout  Votes_Cast  Valid_Votes   Remain    Leave  ...  Leave_pct  \
# 0      3559.86     3331312      3328983  1448616  1880367  ...   0.564847
# 1      3018.09     2510496      2508515  1033036  1475479  ...   0.588188
# 2      2303.97     3781204      3776751  2263519  1513232  ...   0.400670
# 3       829.57     1341387      1340698   562595   778103  ...   0.580372
# 4      2758.82     3668627      3665945  1699020  1966925  ...   0.536540
#
#    Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# ...

# %%
#Agg on Area
df_ref_agg_area = df_ref.groupby(['Area']).sum().reset_index()
df_ref_agg_area['Remain_pct'] = df_ref_agg_area['Remain']/df_ref_agg_area['Valid_Votes']
df_ref_agg_area['Leave_pct'] = df_ref_agg_area['Leave']/df_ref_agg_area['Valid_Votes']
df_ref_agg_area['county_name'] = df_ref_agg_area['Area']
df_ref_agg_area.head()
# Out:
#             Area   id  Electorate  ExpectedBallots  VerifiedBallotPapers  \
# 0  Aberdeen City  148      154266           104809                104809
# 1  Aberdeenshire  149      196809           139014                139014
# 2           Adur  368       48755            37253                 37251
# 3      Allerdale  189       74426            54268                 54268
# 4   Amber Valley  195       96760            73870                 73868
#
#    Pct_Turnout  Votes_Cast  Valid_Votes  Remain  Leave  ...  Leave_pct  \
# 0        67.94      104809       104714   63985  40729  ...   0.388955
# 1        70.63      139014       138961   76445  62516  ...   0.449882
# 2        76.40       37251        37229   16914  20315  ...   0.545677
# 3        72.92       54268        54238   22429  31809  ...   0.586471
# 4        76.34       73864        73820   29319  44501  ...   0.602831
#
#    Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# ...

# %%
df_election_region_join = pd.merge(df_election,
                 df_ref_agg_rgion[['Leave_pct', 'Remain_pct','region_name']],
                 on='region_name', 
                 how='left')

# %%
df_election_area_join = pd.merge(df_election,
                 df_ref_agg_area[['Leave_pct', 'Remain_pct','county_name']],
                 on='county_name', 
                 how='left')

# %%
df_election_area_join
# Out:
#         ons_id ons_region_id          constituency_name  \
# 0    W07000049     W92000004                   Aberavon
# 1    W07000058     W92000004                  Aberconwy
# 2    S14000001     S92000003             Aberdeen North
# 3    S14000002     S92000003             Aberdeen South
# 4    S14000003     S92000003         Airdrie and Shotts
# 5    E14000530     E12000008                  Aldershot
# 6    E14000531     E12000005        Aldridge-Brownhills
# 7    E14000532     E12000002   Altrincham and Sale West
# 8    W07000043     W92000004           Alyn and Deeside
# 9    E14000533     E12000004               Amber Valley
# 10   S14000004     S92000003                      Angus
# 11   W07000057     W92000004                      Arfon
# 12   S14000005     S92000003            Argyll and Bute
# 13   E14000534     E12000008    Arundel and South Downs
# 14   E14000535     E12000004                   Ashfield
# 15   E14000536     E12000008                    Ashford
# ...
